# %%
import gspread

# %%
gc = gspread.service_account(filename="./data-epic-first-task-8d43378807bb.json")

# %%
sh = gc.create('A new spreadsheet')

# %%
print(sh)
# Out:
# <Spreadsheet 'A new spreadsheet' id:1WuR-mVTKgXf649jPyDQm_OehwehLn9bGlZSG8EGcSRE>

# %%
sht1 = gc.open_by_key('1VSijQnpCVpO3Fx5KmyL54J7fkrli4wZFGWkH_uLybnc')

# %%
print(sht1)
# Out:
# <Spreadsheet 'dataepic team' id:1VSijQnpCVpO3Fx5KmyL54J7fkrli4wZFGWkH_uLybnc>

# %%
Dataepic = sht1.sheet1.get_all_records()
print(Dataepic)
# Out:
# [{'rank': 1, 'finalWorth': 211000, 'category': 'Fashion & Retail', 'personName': 'Bernard Arnault & family', 'age': 74, 'selfMade': 'FALSE'}, {'rank': 2, 'finalWorth': 180000, 'category': 'Automotive', 'personName': 'Elon Musk', 'age': 51, 'selfMade': 'TRUE'}, {'rank': 3, 'finalWorth': 114000, 'category': 'Technology', 'personName': 'Jeff Bezos', 'age': 59, 'selfMade': 'TRUE'}, {'rank': 4, 'finalWorth': 107000, 'category': 'Technology', 'personName': 'Larry Ellison', 'age': 78, 'selfMade': 'TRUE'}, {'rank': 5, 'finalWorth': 106000, 'category': 'Finance & Investments', 'personName': 'Warren Buffett', 'age': 92, 'selfMade': 'TRUE'}, {'rank': 6, 'finalWorth': 104000, 'category': 'Technology', 'personName': 'Bill Gates', 'age': 67, 'selfMade': 'TRUE'}, {'rank': 7, 'finalWorth': 94500, 'category': 'Media & Entertainment', 'personName': 'Michael Bloomberg', 'age': 81, 'selfMade': 'TRUE'}, {'rank': 8, 'finalWorth': 93000, 'category': 'Telecom', 'personName': 'Carlos Slim Helu & family', 'ag
# ...

# %%
worksheet = sht1.sheet1

# %%
val = worksheet.acell('B1').value

# %%
print(val)
# Out:
# finalWorth

# %%
worksheet.update('B1', 'Networth!')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13892\2403134151.py:1: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update('B1', 'Networth!')
# {'spreadsheetId': '1VSijQnpCVpO3Fx5KmyL54J7fkrli4wZFGWkH_uLybnc',
#  'updatedRange': 'Sheet1!B1',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
worksheet.update('G1', 'Gender')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13892\155623803.py:1: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update('G1', 'Gender')
# {'spreadsheetId': '1VSijQnpCVpO3Fx5KmyL54J7fkrli4wZFGWkH_uLybnc',
#  'updatedRange': 'Sheet1!G1',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
worksheet.update('G2:G11', 'Male')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13892\1266461581.py:1: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   worksheet.update('G2:G11', 'Male')
# {'spreadsheetId': '1VSijQnpCVpO3Fx5KmyL54J7fkrli4wZFGWkH_uLybnc',
#  'updatedRange': 'Sheet1!G2',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}
